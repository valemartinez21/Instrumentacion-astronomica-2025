# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy import units as u 
from astropy.visualization import ZScaleInterval
from astropy.coordinates import SkyCoord
from matplotlib import colormaps

# %%
#Abrimos imagenes de ciencia, NGC7293, filtro B, 30 segundos
b1 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000520.fit')
b2 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000521.fit')
b3 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000522.fit')
b4 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000523.fit')
b5 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000524.fit')
b6 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000525.fit')
b7 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000526.fit')
b8 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000527.fit')
b9 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000528.fit')
b10 = fits.open('NGC_6618/20251002/filtroB/V462_B_30.000secs_00000530.fit')

b1[0].data
# Out:
# array([[ 87,  95,  91, ..., 100,  92,  89],
#        [ 97, 105, 105, ...,  94,  95,  94],
#        [ 92,  92,  94, ...,  93,  89,  78],
#        ...,
#        [ 95,  95,  91, ...,  95,  83,  81],
#        [ 83,  84,  88, ...,  88,  85,  83],
#        [ 87,  84, 101, ...,  89,  84,  93]], dtype=uint16)

# %%
#Abrimos imagenes de ciencia, NGC7293, filtro V, 600 segundos
v1 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000510.fit')
v2 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000511.fit')
v3 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000512.fit')
v4 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000513.fit')
v5 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000514.fit')
v6 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000515.fit')
v7 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000516.fit')
v8 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000517.fit')
v9 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000518.fit')
v10 = fits.open('NGC_6618/20251002/filtroV/V462_V_30.000secs_00000519.fit')

v1[0].data
# Out:
# array([[ 91,  83,  86, ...,  90,  88,  79],
#        [ 98,  74, 108, ..., 106,  85,  87],
#        [ 97,  91, 103, ...,  84,  92,  84],
#        ...,
#        [ 91,  97,  94, ...,  93,  90,  86],
#        [ 82,  79,  82, ...,  84,  78,  78],
#        [ 88,  97, 105, ...,  79,  77,  87]], dtype=uint16)

# %%
#Extraemos las imagenes
datab1 = b1[0].data
datab2 = b2[0].data
datab3 = b3[0].data
datab4 = b4[0].data
datab5 = b5[0].data
datab6 = b6[0].data
datab7 = b7[0].data
datab8 = b8[0].data
datab9 = b9[0].data
datab10 = b10[0].data

datav1 = v1[0].data
datav2 = v2[0].data
datav3 = v3[0].data
datav4 = v4[0].data
datav5 = v5[0].data
datav6 = v6[0].data
datav7 = v7[0].data
datav8 = v8[0].data
datav9 = v9[0].data
datav10 = v10[0].data

# %%
#Graficamos los primeros raw
zscale = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale.get_limits(datab2) #El datav1 depende de que imagen queramos ver

#Ploteamos al figura
fig = plt.figure(figsize = (5,5))
plt.imshow(datab1 , vmin=min_value , vmax=max_value , cmap='gray' , origin='lower')
plt.title('Imagen Raw filtro B')
plt.show()

#---------------------------------------

fig = plt.figure(figsize = (5,5))
plt.imshow(datav1 , vmin=min_value , vmax=max_value , cmap='gray' , origin='lower')
plt.title('Imagen Raw filtro V')
plt.show()

# %% [markdown]
# ## Bias y Dark

# %%
#Masterbias
bias1 = fits.open('NGC_6618/bias/Bias_1x1_00000494.fit')[0].data
bias2 = fits.open('NGC_6618/bias/Bias_1x1_00000495.fit')[0].data
bias3 = fits.open('NGC_6618/bias/Bias_1x1_00000496.fit')[0].data
bias4 = fits.open('NGC_6618/bias/Bias_1x1_00000497.fit')[0].data
bias5 = fits.open('NGC_6618/bias/Bias_1x1_00000498.fit')[0].data
bias6 = fits.open('NGC_6618/bias/Bias_1x1_00000499.fit')[0].data
bias7 = fits.open('NGC_6618/bias/Bias_1x1_00000500.fit')[0].data
bias8 = fits.open('NGC_6618/bias/Bias_1x1_00000501.fit')[0].data
bias9 = fits.open('NGC_6618/bias/Bias_1x1_00000502.fit')[0].data
bias10 = fits.open('NGC_6618/bias/Bias_1x1_00000503.fit')[0].data

master_bias = np.mean([bias1,bias1,bias3,bias4,bias5,bias6,bias7,bias8,bias9,bias10],axis=0)

#Grafiquemoslo
fig=plt.figure(figsize=(5,5))
zscale=ZScaleInterval(contrast=0.25)
min_value,max_value=zscale.get_limits(master_bias)

plt.imshow(master_bias,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Master Bias')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

# %%
#Master dark reduccion
dark1 = fits.open('NGC_6618/darks/Dark_100.000secs_00000484.fit')[0].data
dark2 = fits.open('NGC_6618/darks/Dark_100.000secs_00000485.fit')[0].data
dark3 = fits.open('NGC_6618/darks/Dark_100.000secs_00000486.fit')[0].data
dark4 = fits.open('NGC_6618/darks/Dark_100.000secs_00000487.fit')[0].data
dark5 = fits.open('NGC_6618/darks/Dark_100.000secs_00000488.fit')[0].data
dark6 = fits.open('NGC_6618/darks/Dark_100.000secs_00000489.fit')[0].data
dark7 = fits.open('NGC_6618/darks/Dark_100.000secs_00000490.fit')[0].data
dark8 = fits.open('NGC_6618/darks/Dark_100.000secs_00000491.fit')[0].data
dark9 = fits.open('NGC_6618/darks/Dark_100.000secs_00000492.fit')[0].data
dark10 = fits.open('NGC_6618/darks/Dark_100.000secs_00000493.fit')[0].data

master_dark = np.median([dark1,dark2,dark3,dark4,dark5,dark6,dark7,dark8,dark9,dark10],axis=0)
dark_current_600 = np.mean([dark1 - master_bias,dark2 - master_bias,dark3 - master_bias,dark4 - master_bias,dark5 - master_bias,dark6 - master_bias,dark7 - master_bias,dark8 - master_bias,dark9 - master_bias,dark10 - master_bias],axis=0)/600
#Grafiquemoslos
fig=plt.figure(figsize=(5,5))
zscale=ZScaleInterval(contrast=0.25)
min_value,max_value=zscale.get_limits(master_dark)

plt.imshow(master_dark,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Master Dark 100 segundos')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

# %%
#Flats y master flat filtro B

flatb1 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-001.fit')[0].data
flatb2 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-002.fit')[0].data
flatb3 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-003.fit')[0].data
flatb4 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-004.fit')[0].data
flatb5 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-005.fit')[0].data
flatb6 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-006.fit')[0].data
flatb7 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-007.fit')[0].data
flatb8 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-008.fit')[0].data
flatb9 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-009.fit')[0].data
flatb10 = fits.open('NGC_6618/Flats/flatB/FLAT_B_B11-010.fit')[0].data

master_flatb = np.median([flatb1,flatb2,flatb3,flatb4,flatb5,flatb6,flatb7,flatb8,flatb9,flatb10],axis=0)
master_flatb_norm  = master_flatb/np.mean(master_flatb)

#Flats y master flat filtro V

flatv1 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-001.fit')[0].data
flatv2 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-002.fit')[0].data
flatv3 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-003.fit')[0].data
flatv4 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-004.fit')[0].data
flatv5 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-005.fit')[0].data
flatv6 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-006.fit')[0].data
flatv7 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-007.fit')[0].data
flatv8 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-008.fit')[0].data
flatv9 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-009.fit')[0].data
flatv10 = fits.open('NGC_6618/Flats/flatV/FLAT_V_B11-010.fit')[0].data

master_flatv = np.median([flatv1,flatv2,flatv3,flatv4,flatv5,flatv6,flatv7,flatv8,flatv9,flatv10],axis=0)
master_flatv_norm  = master_flatv/np.mean(master_flatv)

#Grafiquemos
fig=plt.figure(figsize=(5,5))
zscale=ZScaleInterval(contrast=0.25)
min_value,max_value=zscale.get_limits(master_flatv_norm)

plt.imshow(master_flatv_norm,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Master Flat filtro V normalizado')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

#Grafiquemos
fig=plt.figure(figsize=(5,5))
zscale=ZScaleInterval(contrast=0.25)
min_value,max_value=zscale.get_limits(master_flatb_norm)

plt.imshow(master_flatb_norm,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Master Flat filtro B normalizado')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

# %%
fig = plt.figure(figsize=(5,5))
zscale_b = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale_b.get_limits(datav1-master_dark)

plt.imshow(datav1-master_dark,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Raw filtro V - Master Dark')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

#################################

fig = plt.figure(figsize=(5,5))
zscale_b = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale_b.get_limits(datab1-master_dark)

plt.imshow(datab1-master_dark,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Raw filtro B - Master Dark')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

# %%
#Creamos las imagenes finales para cada filtro

img1b = (datab1-master_dark)/master_flatb_norm
img2b = (datab2-master_dark)/master_flatb_norm
img3b = (datab3-master_dark)/master_flatb_norm
img4b = (datab4-master_dark)/master_flatb_norm
img5b = (datab5-master_dark)/master_flatb_norm
img6b = (datab6-master_dark)/master_flatb_norm
img7b = (datab7-master_dark)/master_flatb_norm
img8b = (datab8-master_dark)/master_flatb_norm
img9b = (datab9-master_dark)/master_flatb_norm
img10b = (datab10-master_dark)/master_flatb_norm

img1v = (datav1-master_dark)/master_flatv_norm
img2v = (datav2-master_dark)/master_flatv_norm
img3v = (datav3-master_dark)/master_flatv_norm
img4v = (datav4-master_dark)/master_flatv_norm
img5v = (datav5-master_dark)/master_flatv_norm
img6v = (datav6-master_dark)/master_flatv_norm
img7v = (datav7-master_dark)/master_flatv_norm
img8v = (datav8-master_dark)/master_flatv_norm
img9v = (datav9-master_dark)/master_flatv_norm
img10v = (datav10-master_dark)/master_flatv_norm

bpm=fits.open('BPM.fit')[0].data

img_final_b = np.mean([img1b,img2b,img3b,img4b,img5b,img6b,img7b,img8b,img9b,img10b],axis=0)*bpm
img_final_v = np.mean([img1v,img2v,img3v,img4v,img5v,img6v,img7v,img8v,img9v,img10v],axis=0)*bpm
# Out:
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:3: RuntimeWarning: invalid value encountered in divide
#   img1b = (datab1-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:4: RuntimeWarning: invalid value encountered in divide
#   img2b = (datab2-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:5: RuntimeWarning: invalid value encountered in divide
#   img3b = (datab3-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:6: RuntimeWarning: invalid value encountered in divide
#   img4b = (datab4-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:7: RuntimeWarning: invalid value encountered in divide
#   img5b = (datab5-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:8: RuntimeWarning: invalid value encountered in divide
#   img6b = (datab6-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:9: RuntimeWarning: invalid value encountered in divide
#   img7b = (datab7-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:10: RuntimeWarning: invalid value encountered in divide
#   img8b = (datab8-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:11: RuntimeWarning: invalid value encountered in divide
#   img9b = (datab9-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:12: RuntimeWarning: invalid value encountered in divide
#   img10b = (datab10-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:14: RuntimeWarning: invalid value encountered in divide
#   img1v = (datav1-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:15: RuntimeWarning: invalid value encountered in divide
#   img2v = (datav2-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:16: RuntimeWarning: invalid value encountered in divide
#   img3v = (datav3-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:17: RuntimeWarning: invalid value encountered in divide
#   img4v = (datav4-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:18: RuntimeWarning: invalid value encountered in divide
#   img5v = (datav5-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:19: RuntimeWarning: invalid value encountered in divide
#   img6v = (datav6-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:20: RuntimeWarning: invalid value encountered in divide
#   img7v = (datav7-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:21: RuntimeWarning: invalid value encountered in divide
#   img8v = (datav8-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:22: RuntimeWarning: invalid value encountered in divide
#   img9v = (datav9-master_dark)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3574393811.py:23: RuntimeWarning: invalid value encountered in divide
#   img10v = (datav10-master_dark)/master_flatv_norm

# %%
#graficamos ambas imagenes

fig = plt.figure(figsize=(5,5))
zscale_b = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale_b.get_limits(img_final_b)

plt.imshow(img_final_b,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen reducida filtro B')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

fig = plt.figure(figsize=(5,5))
zscale_v = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale_v.get_limits(img_final_v)

plt.imshow(img_final_v,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen reducida filtro V')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

# %%
#Creación fits y astrometría

phdu = fits.PrimaryHDU(header = b1[0].header , data = img_final_b)
phdu.data = np.float32(phdu.data)

phdu.header['PIXSCALE'] = 0.36
phdu.header['CTYPE1'] = 'RA---TAN'
phdu.header['CTYPE2'] = 'DEC--TAN'
phdu.header['CRPIX1'] = int(phdu.header['NAXIS1']/2)
phdu.header['CRPIX2'] = int(phdu.header['NAXIS2']/2)

coord = SkyCoord(f"{phdu.header['OBJCTRA']} {phdu.header['OBJCTDEC']}", unit=(u.hourangle, u.deg))#Transformacion de unidades a grados decimales

phdu.header['CRVAL1'] = coord.ra.value
phdu.header['CRVAL2'] = coord.dec.value
phdu.header['CD1_1'] = -0.0001
phdu.header['CD1_2'] = 0
phdu.header['CD2_1'] = 0
phdu.header['CD2_2'] = 0.0001
phdu.header['OBSERVER'] = 'Martinez, Oyarzo, Vargas'

phdu.writeto('Img_B.fits', overwrite = True)

# %%
phdu = fits.PrimaryHDU(header = v1[0].header , data = img_final_v)
phdu.data = np.float32(phdu.data)

phdu.header['PIXSCALE'] = 0.36
phdu.header['CTYPE1'] = 'RA---TAN'
phdu.header['CTYPE2'] = 'DEC--TAN'
phdu.header['CRPIX1'] = int(phdu.header['NAXIS1']/2)
phdu.header['CRPIX2'] = int(phdu.header['NAXIS2']/2)

coord=SkyCoord(f"{phdu.header['OBJCTRA']} {phdu.header['OBJCTDEC']}", unit=(u.hourangle, u.deg)) #Transformacion de unidades a grados decimales

phdu.header['CRVAL1'] = coord.ra.value
phdu.header['CRVAL2'] = coord.dec.value
phdu.header['CD1_1'] = -0.0001
phdu.header['CD1_2'] = 0
phdu.header['CD2_1'] = 0
phdu.header['CD2_2'] = 0.0001
phdu.header['OBSERVER'] = 'Martinez, Oyarzo, Vargas'

phdu.writeto('Img_V.fits', overwrite = True)

# %%
#Vemos que informacion tiene el fits creado
test1 = fits.open('Img_B.fits')
test1[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4096
# NAXIS2  =                 4096
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# OBSERVER= 'Martinez, Oyarzo, Vargas' / SBIGFITSEXT The name of the observer
# ORIGIN  = 'MAS500  '           / Description of location
# TELESCOP= 'MAS500  '           / SBIGFITSEXT The model Telescope
# FOCALLEN=                6500. / SBIGFITSEXT Telescope focal length in mm
# APTDIA  =                 500. / SBIGFITSEXT Aperture diameter in mm
# SBUUID  = '{36922ce2-fadc-4106-aca6-27392ccf34c3}' / Photo UUID
# EXPTIME =                  30. / SBIGFITSEXT Total exposure time in seconds
# SWCREATE= 'TheSkyX Version 10.5.0 Build 12545' / SBIGFITSEXT Name & version of s
# COLORCCD=                    0 / Non zero if image is from a Bayer color ccd
# DISPINCR=                    1 / Non zero to automatically display the image in
# PICTTYPE=                    1 / Image type as index 0= Unknown 1=Light, 2=Bias,
# IMAGETYP= 'Light Frame'        / SBIGFITSEXT Light, Dark, Bias or Flat
# XORGSUBF=                    0 / SBIGFITSEXT Subframe x upper-left pixel in bin
# YORGSUBF=                    0 / SBIGFITSEXT Subframe y upper-left pixel in bin
# XBINNING=                    1 / SBIGFITSEXT Binning factor in width
# YBINNING=                    1 / SBIGFITSEXT Binning factor in height
# CCD-TEMP=                -14.3 / SBIGFITSEXT Temperature of the CCD
# SET-TEMP=                 -16. / SBIGFITSEXT The cooler setpoint in degrees C
# SITELAT = '-30 27 35.00'       / SBIGFITSEXT Latitude of the imaging location
# SITELONG= '+70 45 01.00'       / SBIGFITSEXT Longitude of the imaging location
# LST     = '+19 56 48.54'       / Local sidereal time
# OBSGEO-B=    -30.4597222222222 / Latitude of the observation in degrees, North +
# OBSGEO-L=    -70.7502777777778 / Longitude of the observation in degrees, East +
# OBSGEO-H=                1600. / Altitude of the observation in meters
# BTP     =                    0 / Beyond the pole
# CENTAZ  =     298.163630583659 / SBIGFITSEXT Azimuth of the center of the image
# CENTALT =     64.1172200841155 / SBIGFITSEXT Altitude of the center of the image
# AIRMASS =     1.11149361740015 / Airmass of the telescope
# TELEHA  = '+01 34 29.24'       / Telescope hour angle
# MOUNT   = 'ASCOM Mount'        / The telescope mount
# OBJCTRA = '18 20 50.076'       / SBIGFITSEXT The right ascension of the center o
# OBJCTDEC= '-16 10 51.73'       / SBIGFITSEXT The declination of the center of th
# OBJECT  = 'NGC 6618'           / SBIGFITSEXT The name of the object imaged
# INSTRUME= 'Gx/Cx USB'          / SBIGFITSEXT The model camera used.
# XPIXSZ  =                   9. / SBIGFITSEXT Pixel width in microns after binnin
# YPIXSZ  =                   9. / SBIGFITSEXT Pixel height in microns after binni
# FOCPOS  =                2157. / The focuser position.
# FOCTEMP =     20.1937408447266 / The focuser temperature in degrees C.
# FOCTMPSC= 'Focuser (Default)'  / The focuser temperature source.
# FILTER  = 'B       '           / SBIGFITSEXT The optical filter used to take ima
# DATE-OBS= '2025-10-02T23:52:02.157' / SBIGFITSEXT UTC of start exp. in ISO 8601
# GAIN    =    0.850000023841858 / Camera gain in e-/ADU
# PIXSCALE=                 0.36
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# CRPIX1  =                 2048
# CRPIX2  =                 2048
# CRVAL1  =    275.2086499999999
# CRVAL2  =  -16.181036111111112
# CD1_1   =              -0.0001
# CD1_2   =                    0
# CD2_1   =                    0
# CD2_2   =               0.0001

# %%
test2 = fits.open('Img_V.fits')
test2[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 4096
# NAXIS2  =                 4096
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# OBSERVER= 'Martinez, Oyarzo, Vargas' / SBIGFITSEXT The name of the observer
# ORIGIN  = 'MAS500  '           / Description of location
# TELESCOP= 'MAS500  '           / SBIGFITSEXT The model Telescope
# FOCALLEN=                6500. / SBIGFITSEXT Telescope focal length in mm
# APTDIA  =                 500. / SBIGFITSEXT Aperture diameter in mm
# SBUUID  = '{7524519a-ed8c-4d5c-96cf-27a49afa87d7}' / Photo UUID
# EXPTIME =                  30. / SBIGFITSEXT Total exposure time in seconds
# SWCREATE= 'TheSkyX Version 10.5.0 Build 12545' / SBIGFITSEXT Name & version of s
# COLORCCD=                    0 / Non zero if image is from a Bayer color ccd
# DISPINCR=                    1 / Non zero to automatically display the image in
# PICTTYPE=                    1 / Image type as index 0= Unknown 1=Light, 2=Bias,
# IMAGETYP= 'Light Frame'        / SBIGFITSEXT Light, Dark, Bias or Flat
# XORGSUBF=                    0 / SBIGFITSEXT Subframe x upper-left pixel in bin
# YORGSUBF=                    0 / SBIGFITSEXT Subframe y upper-left pixel in bin
# XBINNING=                    1 / SBIGFITSEXT Binning factor in width
# YBINNING=                    1 / SBIGFITSEXT Binning factor in height
# CCD-TEMP=                -14.2 / SBIGFITSEXT Temperature of the CCD
# SET-TEMP=                 -16. / SBIGFITSEXT The cooler setpoint in degrees C
# SITELAT = '-30 27 35.00'       / SBIGFITSEXT Latitude of the imaging location
# SITELONG= '+70 45 01.00'       / SBIGFITSEXT Longitude of the imaging location
# LST     = '+19 51 28.47'       / Local sidereal time
# OBSGEO-B=    -30.4597222222222 / Latitude of the observation in degrees, North +
# OBSGEO-L=    -70.7502777777778 / Longitude of the observation in degrees, East +
# OBSGEO-H=                1600. / Altitude of the observation in meters
# BTP     =                    0 / Beyond the pole
# CENTAZ  =     300.017244000507 / SBIGFITSEXT Azimuth of the center of the image
# CENTALT =     65.1215005764712 / SBIGFITSEXT Altitude of the center of the image
# AIRMASS =     1.10228899575199 / Airmass of the telescope
# TELEHA  = '+01 29 09.27'       / Telescope hour angle
# MOUNT   = 'ASCOM Mount'        / The telescope mount
# OBJCTRA = '18 20 49.976'       / SBIGFITSEXT The right ascension of the center o
# OBJCTDEC= '-16 10 51.72'       / SBIGFITSEXT The declination of the center of th
# OBJECT  = 'NGC 6618'           / SBIGFITSEXT The name of the object imaged
# INSTRUME= 'Gx/Cx USB'          / SBIGFITSEXT The model camera used.
# XPIXSZ  =                   9. / SBIGFITSEXT Pixel width in microns after binnin
# YPIXSZ  =                   9. / SBIGFITSEXT Pixel height in microns after binni
# FOCPOS  =                2157. / The focuser position.
# FOCTEMP =     20.5010395050049 / The focuser temperature in degrees C.
# FOCTMPSC= 'Focuser (Default)'  / The focuser temperature source.
# FILTER  = 'V       '           / SBIGFITSEXT The optical filter used to take ima
# DATE-OBS= '2025-10-02T23:46:50.095' / SBIGFITSEXT UTC of start exp. in ISO 8601
# GAIN    =    0.850000023841858 / Camera gain in e-/ADU
# PIXSCALE=                 0.36
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# CRPIX1  =                 2048
# CRPIX2  =                 2048
# CRVAL1  =    275.2082333333333
# CRVAL2  =  -16.181033333333335
# CD1_1   =              -0.0001
# CD1_2   =                    0
# CD2_1   =                    0
# CD2_2   =               0.0001

# %% [markdown]
# ## Estrellas

# %%
#Realizamos la reduccion de las estrellas del mismo modos que las imagen del objeto

star1_1B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000557.fit')
star1_2B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000558.fit')
star1_3B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000559.fit')
star1_4B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000560.fit')
star1_5B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000561.fit')
star1_6B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000562.fit')
star1_7B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000563.fit')
star1_8B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000564.fit')
star1_9B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000565.fit')
star1_10B = fits.open('NGC_6618/Estrellas/HIP_116375/B/V462_B_5.000secs_00000566.fit')

star1_1V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000547.fit')
star1_2V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000548.fit')
star1_3V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000549.fit')
star1_4V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000550.fit')
star1_5V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000551.fit')
star1_6V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000552.fit')
star1_7V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000553.fit')
star1_8V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000554.fit')
star1_9V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000555.fit')
star1_10V = fits.open('NGC_6618/Estrellas/HIP_116375/V/V462_V_3.000secs_00000556.fit')

star2_1B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000592.fit')
star2_2B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000593.fit')
star2_3B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000594.fit')
star2_4B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000595.fit')
star2_5B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000596.fit')
star2_6B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000597.fit')
star2_7B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000598.fit')
star2_8B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000599.fit')
star2_9B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000600.fit')
star2_10B = fits.open('NGC_6618/Estrellas/HIP_117678/B/V462_B_5.000secs_00000601.fit')

star2_1V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000602.fit')
star2_2V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000603.fit')
star2_3V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000604.fit')
star2_4V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000605.fit')
star2_5V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000606.fit')
star2_6V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000607.fit')
star2_7V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000608.fit')
star2_8V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000609.fit')
star2_9V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000610.fit')
star2_10V = fits.open('NGC_6618/Estrellas/HIP_117678/V/V462_V_3.000secs_00000611.fit')

dark_current =(master_dark - master_bias)

red_star_1B_1 = (star1_1B[0].data-master_dark)/master_flatb_norm
red_star_1B_2 = (star1_2B[0].data-master_dark)/master_flatb_norm
red_star_1B_3 = (star1_3B[0].data-master_dark)/master_flatb_norm
red_star_1B_4 = (star1_4B[0].data-master_dark)/master_flatb_norm
red_star_1B_5 = (star1_5B[0].data-master_dark)/master_flatb_norm
red_star_1B_6 = (star1_6B[0].data-master_dark)/master_flatb_norm
red_star_1B_7 = (star1_7B[0].data-master_dark)/master_flatb_norm
red_star_1B_8 = (star1_8B[0].data-master_dark)/master_flatb_norm
red_star_1B_9 = (star1_9B[0].data-master_dark)/master_flatb_norm
red_star_1B_10 = (star1_10B[0].data-master_dark)/master_flatb_norm

red_star_1V_1 = (star1_1V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_1V_2 = (star1_2V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_1V_3 = (star1_3V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_1V_4 = (star1_4V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_1V_5 = (star1_5V[0].data-master_bias-dark_current*5)/master_flatv_norm

red_star_2B_1 = (star2_1B[0].data-master_dark)/master_flatb_norm
red_star_2B_2 = (star2_2B[0].data-master_dark)/master_flatb_norm
red_star_2B_3 = (star2_3B[0].data-master_dark)/master_flatb_norm
red_star_2B_4 = (star2_4B[0].data-master_dark)/master_flatb_norm
red_star_2B_5 = (star2_5B[0].data-master_dark)/master_flatb_norm
red_star_2B_6 = (star2_6B[0].data-master_dark)/master_flatb_norm
red_star_2B_7 = (star2_7B[0].data-master_dark)/master_flatb_norm
red_star_2B_8 = (star2_8B[0].data-master_dark)/master_flatb_norm
red_star_2B_9 = (star2_9B[0].data-master_dark)/master_flatb_norm
red_star_2B_10 = (star2_10B[0].data-master_dark)/master_flatb_norm

red_star_2V_1 = (star2_1V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_2 = (star2_2V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_3 = (star2_3V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_4 = (star2_4V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_5 = (star2_5V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_6 = (star2_6V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_7 = (star2_7V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_8 = (star2_8V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_9 = (star2_9V[0].data-master_bias-dark_current*5)/master_flatv_norm
red_star_2V_10 = (star2_10V[0].data-master_bias-dark_current*5)/master_flatv_norm
# Out:
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:49: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_1 = (star1_1B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:50: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_2 = (star1_2B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:51: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_3 = (star1_3B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:52: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_4 = (star1_4B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:53: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_5 = (star1_5B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:54: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_6 = (star1_6B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:55: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_7 = (star1_7B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:56: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_8 = (star1_8B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:57: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_9 = (star1_9B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:58: RuntimeWarning: invalid value encountered in divide
#   red_star_1B_10 = (star1_10B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:60: RuntimeWarning: invalid value encountered in divide
#   red_star_1V_1 = (star1_1V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:61: RuntimeWarning: invalid value encountered in divide
#   red_star_1V_2 = (star1_2V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:62: RuntimeWarning: invalid value encountered in divide
#   red_star_1V_3 = (star1_3V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:63: RuntimeWarning: invalid value encountered in divide
#   red_star_1V_4 = (star1_4V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:64: RuntimeWarning: invalid value encountered in divide
#   red_star_1V_5 = (star1_5V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:66: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_1 = (star2_1B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:67: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_2 = (star2_2B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:68: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_3 = (star2_3B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:69: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_4 = (star2_4B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:70: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_5 = (star2_5B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:71: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_6 = (star2_6B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:72: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_7 = (star2_7B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:73: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_8 = (star2_8B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:74: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_9 = (star2_9B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:75: RuntimeWarning: invalid value encountered in divide
#   red_star_2B_10 = (star2_10B[0].data-master_dark)/master_flatb_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:77: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_1 = (star2_1V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:78: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_2 = (star2_2V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:79: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_3 = (star2_3V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:80: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_4 = (star2_4V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:81: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_5 = (star2_5V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:82: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_6 = (star2_6V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:83: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_7 = (star2_7V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:84: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_8 = (star2_8V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:85: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_9 = (star2_9V[0].data-master_bias-dark_current*5)/master_flatv_norm
# C:\Users\Valem\AppData\Local\Temp\ipykernel_16292\3187839609.py:86: RuntimeWarning: invalid value encountered in divide
#   red_star_2V_10 = (star2_10V[0].data-master_bias-dark_current*5)/master_flatv_norm

# %%
#Garficamos primeras imagenes de estrella por filtro
fig = plt.figure(figsize=(5,5))
zscale_b = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale_b.get_limits(star1_1B[0].data)

plt.imshow(star1_1B[0].data,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen Raw HIP 116375 filtro B')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

fig = plt.figure(figsize=(5,5))
zscale_b = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale_b.get_limits(star1_1V[0].data)

plt.imshow(star1_1V[0].data,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen Raw HIP 116375 filtro V')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

fig = plt.figure(figsize=(5,5))
zscale_b = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale_b.get_limits(star2_1B[0].data)

plt.imshow(star2_1B[0].data,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen Raw HIP 117678 filtro B')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

fig = plt.figure(figsize=(5,5))
zscale_b = ZScaleInterval(contrast=0.25)
min_value,max_value = zscale_b.get_limits(star2_1V[0].data)

plt.imshow(star2_1V[0].data,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen Raw HIP 117678 filtro v')
plt.colorbar(label='Intensidad [ADU]')
plt.show()

# %%
#Imagenes finales
final_star1B = np.mean([red_star_1B_1,red_star_1B_2,red_star_1B_3,red_star_1B_4,red_star_1B_5],axis=0)*bpm
fig=plt.figure(figsize=(5,5))
zscale_1=ZScaleInterval(contrast=0.25)
min_value,max_value=zscale_1.get_limits(final_star1B)

plt.imshow(final_star1B,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen reducida HIP 116375 filtro B')
plt.show()


final_star1V = np.mean([red_star_1V_1,red_star_1V_2,red_star_1V_3,red_star_1V_4,red_star_1V_5],axis=0)*bpm
fig=plt.figure(figsize=(5,5))
zscale_2=ZScaleInterval(contrast=0.25)
min_value,max_value=zscale_2.get_limits(final_star1V )

plt.imshow(final_star1V ,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen reducida HIP 116375 filtro V')
plt.show()


final_star2B = np.mean([red_star_2B_1,red_star_2B_2,red_star_2B_3,red_star_2B_4,red_star_2B_5],axis=0)*bpm
fig=plt.figure(figsize=(5,5))
zscale_3=ZScaleInterval(contrast=0.25)
min_value,max_value=zscale_3.get_limits(final_star2B)

plt.imshow(final_star2B,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen reducida HIP 117678 filtro B')
plt.show()



final_star2V = np.mean([red_star_2V_1,red_star_2V_2,red_star_2V_3,red_star_2V_4,red_star_2V_5],axis=0)*bpm
fig=plt.figure(figsize=(5,5))
zscale_4=ZScaleInterval(contrast=0.25)
min_value,max_value=zscale_4.get_limits(final_star2V)

plt.imshow(final_star2V,vmin=min_value,vmax=max_value,cmap='gray',origin='lower')
plt.title('Imagen reducida HIP 117678 filtro V')
plt.show()

# %%
phdu = fits.PrimaryHDU(header = star1_1B[0].header , data = final_star1B)
phdu.data = np.float32(phdu.data)

phdu.header['PIXSCALE'] = 0.36
phdu.header['CTYPE1'] = 'RA---TAN'
phdu.header['CTYPE2'] = 'DEC--TAN'
phdu.header['CRPIX1'] = int(phdu.header['NAXIS1']/2)
phdu.header['CRPIX2'] = int(phdu.header['NAXIS2']/2)

coord=SkyCoord(f'{phdu.header['OBJCTRA']} {phdu.header['OBJCTDEC']}', unit=(u.hourangle, u.deg)) #Transformacion de unidades a grados decimales

phdu.header['CRVAL1'] = coord.ra.value
phdu.header['CRVAL2'] = coord.dec.value
phdu.header['CD1_1'] = -0.0001
phdu.header['CD1_2'] = 0
phdu.header['CD2_1'] = 0
phdu.header['CD2_2'] = 0.0001
phdu.header['OBSERVER'] = 'Cortes, G. Guerrero, Martinez'

phdu.writeto('Star1_B.fits', overwrite = True)

#-----------------------------------------------------------------------

phdu = fits.PrimaryHDU(header = star1_1V[0].header , data = final_star1V)
phdu.data = np.float32(phdu.data)

phdu.header['PIXSCALE'] = 0.36
phdu.header['CTYPE1'] = 'RA---TAN'
phdu.header['CTYPE2'] = 'DEC--TAN'
phdu.header['CRPIX1'] = int(phdu.header['NAXIS1']/2)
phdu.header['CRPIX2'] = int(phdu.header['NAXIS2']/2)

coord=SkyCoord(f'{phdu.header['OBJCTRA']} {phdu.header['OBJCTDEC']}', unit=(u.hourangle, u.deg)) #Transformacion de unidades a grados decimales

phdu.header['CRVAL1'] = coord.ra.value
phdu.header['CRVAL2'] = coord.dec.value
phdu.header['CD1_1'] = -0.0001
phdu.header['CD1_2'] = 0
phdu.header['CD2_1'] = 0
phdu.header['CD2_2'] = 0.0001
phdu.header['OBSERVER'] = 'Cortes, G. Guerrero, Martinez'

phdu.writeto('Star1_V.fits', overwrite = True)

#-----------------------------------------------------------------------

phdu = fits.PrimaryHDU(header = star2_1B[0].header , data = final_star2B)
phdu.data = np.float32(phdu.data)

phdu.header['PIXSCALE'] = 0.36
phdu.header['CTYPE1'] = 'RA---TAN'
phdu.header['CTYPE2'] = 'DEC--TAN'
phdu.header['CRPIX1'] = int(phdu.header['NAXIS1']/2)
phdu.header['CRPIX2'] = int(phdu.header['NAXIS2']/2)

coord=SkyCoord(f'{phdu.header['OBJCTRA']} {phdu.header['OBJCTDEC']}', unit=(u.hourangle, u.deg)) #Transformacion de unidades a grados decimales

phdu.header['CRVAL1'] = coord.ra.value
phdu.header['CRVAL2'] = coord.dec.value
phdu.header['CD1_1'] = -0.0001
phdu.header['CD1_2'] = 0
phdu.header['CD2_1'] = 0
phdu.header['CD2_2'] = 0.0001
phdu.header['OBSERVER'] = 'Cortes, G. Guerrero, Martinez'

phdu.writeto('Star2_B.fits', overwrite = True)

#-----------------------------------------------------------------------

phdu = fits.PrimaryHDU(header = star2_1V[0].header , data = final_star2V)
phdu.data = np.float32(phdu.data)

phdu.header['PIXSCALE'] = 0.36
phdu.header['CTYPE1'] = 'RA---TAN'
phdu.header['CTYPE2'] = 'DEC--TAN'
phdu.header['CRPIX1'] = int(phdu.header['NAXIS1']/2)
phdu.header['CRPIX2'] = int(phdu.header['NAXIS2']/2)

coord=SkyCoord(f'{phdu.header['OBJCTRA']} {phdu.header['OBJCTDEC']}', unit=(u.hourangle, u.deg)) #Transformacion de unidades a grados decimales

phdu.header['CRVAL1'] = coord.ra.value
phdu.header['CRVAL2'] = coord.dec.value
phdu.header['CD1_1'] = -0.0001
phdu.header['CD1_2'] = 0
phdu.header['CD2_1'] = 0
phdu.header['CD2_2'] = 0.0001
phdu.header['OBSERVER'] = 'Cortes, G. Guerrero, Martinez'

phdu.writeto('Star2_V.fits', overwrite = True)
